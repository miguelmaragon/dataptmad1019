# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
fee = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
fee.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
fee.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
for x in fee.entries:
    print(x.title)
    #print(x.subtitle)
    print(x.author)    
    print(x.link)
# Out:
# The road to Software 2.0
# Mike Loukides and Ben Lorica
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/nbtg4a0T0UI/
# Four short links: 10 December 2019
# Nat Torkington
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/J8hN_h1ZiOo/
# Four short links: 9 December 2019
# Nat Torkington
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9brHkJ-0XOk/
# Four short links: 6 December 2019
# Nat Torkington
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/2tWwXYPaQQc/
# Radar trends to watch: December 2019
# Mike Loukides
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/TvZqwwslBkc/
# Four short links: 5 December 2019
# Nat Torkington
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/cBpSwHnZOJE/
# Four short links: 4 December 2019
# Nat Torkington
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DV4ZdRtk1ws/
# Use your people as competitive advantage
# Pamela Rucker
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MGgJFA4urls/
# ...

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len([x for x in fee.entries])
# Out:
# 18

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
w=[]
for y in fee.entries:
    w.append(y.title)
w
# Out:
# ['The road to Software 2.0',
#  'Four short links: 10 December 2019',
#  'Four short links: 9 December 2019',
#  'Four short links: 6 December 2019',
#  'Radar trends to watch: December 2019',
#  'Four short links: 5 December 2019',
#  'Four short links: 4 December 2019',
#  'Use your people as competitive advantage',
#  'Four short links: 3 December 2019',
#  'A 5G future',
#  'Four short links: 2 December 2019',
#  'Four short links: 29 November 2019',
#  'Four short links: 28 November 2019',
#  'Four short links: 27 November 2019',
#  'Moving AI and ML from research into production',
#  'Four short links: 26 November 2019',
#  'Four short links: 25 November 2019',
#  'Four short links: 22 November 2019']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
title_four = [r.title for r in fee.entries if r.title.startswith('Four short links')]
len(title_four)
per_title_four = len(title_four)*100/len(w)
per_title_four
# Out:
# 72.22222222222223

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
data = pd.DataFrame(fee.entries)
data
# Out:
#                                              title  \
# 0                         The road to Software 2.0
# 1               Four short links: 10 December 2019
# 2                Four short links: 9 December 2019
# 3                Four short links: 6 December 2019
# 4             Radar trends to watch: December 2019
# 5                Four short links: 5 December 2019
# 6                Four short links: 4 December 2019
# 7         Use your people as competitive advantage
# 8                Four short links: 3 December 2019
# 9                                      A 5G future
# 10               Four short links: 2 December 2019
# 11              Four short links: 29 November 2019
# 12              Four short links: 28 November 2019
# 13              Four short links: 27 November 2019
# 14  Moving AI and ML from research into production
# 15              Four short links: 26 November 2019
# 16              Four short links: 25 November 2019
# ...

# %%
data[['author', 'title']]
# Out:
#                           author  \
# 0   Mike Loukides and Ben Lorica
# 1                 Nat Torkington
# 2                 Nat Torkington
# 3                 Nat Torkington
# 4                  Mike Loukides
# 5                 Nat Torkington
# 6                 Nat Torkington
# 7                  Pamela Rucker
# 8                 Nat Torkington
# 9                  Mike Loukides
# 10                Nat Torkington
# 11                Nat Torkington
# 12                Nat Torkington
# 13                Nat Torkington
# 14                     Jenn Webb
# 15                Nat Torkington
# 16                Nat Torkington
# 17                Nat Torkington
#
#                                              title
# 0                         The road to Software 2.0
# 1               Four short links: 10 December 2019
# 2                Four short links: 9 December 2019
# 3                Four short links: 6 December 2019
# 4             Radar trends to watch: December 2019
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
data_count = data[['author', 'title']].groupby('author').count().sort_values('title', ascending=False)
data_count
# Out:
#                               title
# author
# Nat Torkington                   13
# Mike Loukides                     2
# Jenn Webb                         1
# Mike Loukides and Ben Lorica      1
# Pamela Rucker                     1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
data['length_title'] = data['title'].str.len()
data[['author', 'title','length_title']].sort_values(by=['length_title'],ascending=False)
# Out:
#                           author  \
# 14                     Jenn Webb
# 7                  Pamela Rucker
# 4                  Mike Loukides
# 17                Nat Torkington
# 16                Nat Torkington
# 1                 Nat Torkington
# 11                Nat Torkington
# 12                Nat Torkington
# 13                Nat Torkington
# 15                Nat Torkington
# 2                 Nat Torkington
# 3                 Nat Torkington
# 5                 Nat Torkington
# 6                 Nat Torkington
# 8                 Nat Torkington
# 10                Nat Torkington
# 0   Mike Loukides and Ben Lorica
# 9                  Mike Loukides
#
#                                              title  length_title
# 14  Moving AI and ML from research into production            46
# 7         Use your people as competitive advantage            40
# 4             Radar trends to watch: December 2019            36
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
list_data = data[data['summary'].str.contains("machine learning")]

# %%
list(list_data['title'])
# Out:
# ['The road to Software 2.0', 'Moving AI and ML from research into production']
